# %%
# %pylab inline
import sympy
from IPython.display import display, Math
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
x = linspace(0,2*pi)
plot(x,sin(x))

# %%
a,b,c = sympy.symbols('a b c')
print(a*b*c)
display(Math('$%s$'%sympy.latex((a**5).diff())))
# Out:
# a*b*c
# $$5 a^{4}$$
